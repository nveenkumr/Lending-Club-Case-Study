# %%
#import libraries
# %config IPCompleter.greedy=True
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels
import statsmodels.api as sm 
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 200)

# %%
import statsmodels.api as sm
# Out:
# C:\Users\v-kunav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\v-kunav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# -cipy                              1.2.1
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.2
# asn1crypto                         0.24.0
# astroid                            2.2.5
# astropy                            3.1.2
# atomicwrites                       1.3.0
# attrs                              20.1.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.7.1
# bitarray                           0.8.3
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              1.0.4
# boto                               2.49.0
# Bottleneck                         1.2.1
# certifi                            2020.6.20
# cffi                               1.12.2
# chardet                            3.0.4
# Click                              7.0
# cloudpickle                        0.8.0
# clyent                             1.2.2
# colorama                           0.4.1
# comtypes                           1.1.7
# conda                              4.8.4
# conda-build                        3.17.8
# conda-package-handling             1.3.11
# conda-verify                       3.1.1
# confuse                            1.3.0
# contextlib2                        0.5.5
# cryptography                       2.6.1
# cycler                             0.10.0
# Cython                             0.29.21
# cytoolz                            0.9.0.1
# dask                               1.1.4
# decorator                          4.4.0
# defusedxml                         0.5.0
# distributed                        1.26.0
# docutils                           0.14
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.0.2
# filelock                           3.0.10
# Flask                              1.0.2
# fsspec                             0.8.0
# future                             0.17.1
# gevent                             1.4.0
# glob2                              0.6
# greenlet                           0.4.15
# h5py                               2.9.0
# heapdict                           1.0.0
# html5lib                           1.0.1
# htmlmin                            0.1.12
# idna                               2.8
# ImageHash                          4.1.0
# imageio                            2.5.0
# imagesize                          1.1.0
# importlib-metadata                 0.0.0
# ipykernel                          5.1.0
# ipython                            7.4.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.16
# itsdangerous                       1.1.0
# jdcal                              1.4
# jedi                               0.13.3
# Jinja2                             2.11.2
# joblib                             0.16.0
# json5                              0.9.5
# jsonschema                         3.0.1
# jupyter                            1.0.0
# jupyter-client                     5.2.4
# jupyter-console                    6.0.0
# jupyter-core                       4.4.0
# jupyterlab                         0.35.4
# jupyterlab-server                  0.2.0
# keyring                            18.0.0
# kiwisolver                         1.0.1
# lazy-object-proxy                  1.3.1
# libarchive-c                       2.8
# llvmlite                           0.28.0
# locket                             0.2.0
# lxml                               4.3.2
# MarkupSafe                         1.1.1
# matplotlib                         3.3.1
# mccabe                             0.6.1
# menuinst                           1.4.16
# missingno                          0.4.2
# mistune                            0.8.4
# mkl-fft                            1.0.10
# mkl-random                         1.0.2
# mock                               4.0.2
# more-itertools                     6.0.0
# MouseInfo                          0.1.3
# mpmath                             1.1.0
# msgpack                            0.6.1
# multipledispatch                   0.6.0
# mysql-connector-python             8.0.20
# navigator-updater                  0.2.1
# nbconvert                          5.4.1
# nbformat                           4.4.0
# networkx                           2.4
# nltk                               3.4
# nose                               1.3.7
# notebook                           5.7.8
# numba                              0.43.1
# numexpr                            2.6.9
# numpy                              1.16.2
# numpydoc                           0.8.0
# olefile                            0.46
# openpyxl                           2.6.1
# packaging                          19.0
# pandas                             1.1.1
# pandas-profiling                   2.9.0rc1
# pandocfilters                      1.4.2
# parso                              0.3.4
# partd                              0.3.10
# path.py                            11.5.0
# pathlib2                           2.3.3
# patsy                              0.5.1
# pep8                               1.7.1
# phik                               0.10.0
# pickleshare                        0.7.5
# Pillow                             7.2.0
# pip                                20.2.2
# pkginfo                            1.5.0.1
# plotly                             4.8.2
# pluggy                             0.9.0
# ply                                3.11
# prometheus-client                  0.6.0
# prompt-toolkit                     2.0.9
# psutil                             5.6.1
# py                                 1.8.0
# PyAutoGUI                          0.9.50
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.2
# pyflakes                           2.1.1
# PyGetWindow                        0.0.8
# Pygments                           2.3.1
# pylint                             2.3.1
# PyMsgBox                           1.0.8
# pyodbc                             4.0.26
# pyOpenSSL                          19.0.0
# pyparsing                          2.3.1
# PyPDF2                             1.26.0
# pyperclip                          1.8.0
# pyreadline                         2.1
# PyRect                             0.1.4
# pyrsistent                         0.14.11
# PyScreeze                          0.1.26
# PySocks                            1.6.8
# pytest                             4.3.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.3.0
# pytest-openfiles                   0.3.2
# pytest-remotedata                  0.3.1
# python-dateutil                    2.8.0
# PyTweening                         1.0.3
# pytz                               2018.9
# PyWavelets                         1.0.2
# pywin32                            223
# pywinpty                           0.5.5
# PyYAML                             5.1
# pyzmq                              18.0.0
# QtAwesome                          0.5.7
# qtconsole                          4.4.3
# QtPy                               1.7.0
# requests                           2.24.0
# retrying                           1.3.3
# rope                               0.12.0
# rope-py3k                          0.9.4.post1
# ruamel-yaml                        0.15.46
# scikit-image                       0.14.2
# scikit-learn                       0.20.3
# scipy                              1.5.2
# seaborn                            0.10.1
# Send2Trash                         1.5.0
# setuptools                         49.6.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.12.0
# snowballstemmer                    1.2.1
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.8
# Sphinx                             1.8.5
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.1.0
# spyder                             3.3.3
# spyder-kernels                     0.4.2
# SQLAlchemy                         1.3.1
# statsmodels                        0.9.0
# sympy                              1.3
# tables                             3.5.1
# tangled-up-in-unicode              0.0.6
# tblib                              1.3.2
# terminado                          0.8.1
# testpath                           0.4.2
# toolz                              0.9.0
# tornado                            6.0.2
# tqdm                               4.48.2
# traitlets                          4.3.2
# unicodecsv                         0.14.1
# urllib3                            1.24.1
# visions                            0.4.4
# wcwidth                            0.1.7
# webencodings                       0.5.1
# Werkzeug                           0.14.1
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.1
# xlrd                               1.2.0
# XlsxWriter                         1.1.5
# xlwings                            0.15.4
# xlwt                               1.3.0
# zict                               0.1.4
# zipp                               0.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install --upgrade git+https://github.com/statsmodels/statsmodels

# %%
#pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels==0.10.0rc2 --pre --user
# Out:
# Requirement already satisfied: statsmodels==0.10.0rc2 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (0.10.0rc2)
# Requirement already satisfied: pandas>=0.19 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from statsmodels==0.10.0rc2) (1.1.1)
# Requirement already satisfied: scipy>=0.18 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from statsmodels==0.10.0rc2) (1.5.2)
# Requirement already satisfied: numpy>=1.11 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from statsmodels==0.10.0rc2) (1.16.2)
# Requirement already satisfied: patsy>=0.4.0 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from statsmodels==0.10.0rc2) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from pandas>=0.19->statsmodels==0.10.0rc2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from pandas>=0.19->statsmodels==0.10.0rc2) (2.8.0)
# Requirement already satisfied: six in c:\users\v-kunav\appdata\local\continuum\anaconda3\lib\site-packages (from patsy>=0.4.0->statsmodels==0.10.0rc2) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
